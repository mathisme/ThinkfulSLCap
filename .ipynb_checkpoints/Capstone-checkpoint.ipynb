# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import (precision_recall_fscore_support, plot_confusion_matrix, plot_precision_recall_curve,
   confusion_matrix, precision_recall_curve, ConfusionMatrixDisplay, PrecisionRecallDisplay, f1_score)
from imblearn.pipeline import Pipeline as imbPipeline
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from scipy.stats.mstats import winsorize

# %% [markdown]
# # Table of Contents
# *need to do*

# %% [markdown]
# # Question: What machine learning algorithm can be used to help lenders determine if a potential client will pay back their loan?
#
# # Introduction
#
# A lending company evaluating the application of a potential new client would of course want to know the probability the loan will be repaid.  If the potential client is granted the loan but does not pay it back, the lending company loses money.  If the client is rejected but in fact would have paid back the loan, the lending company loses a potential client and again loses money, abeit not as much, in the interest that would have been collected.  The goal of this project, given the dataset available, is to determine which machine learning algorithm is suitable to help determine if a potential client will or will not pay back their lown.

# %% [markdown]
# # Data
#
# The dataset I chose for the project can be found here on Kaggle. https://www.kaggle.com/itssuru/loan-data  The data was provided by Kaggle user ItsSuru.  It is a loan data dataset gathered from publicly available data from LendingClub.com.  The intent of the data is to create a model to predict whether or not a borrower will pay back their loan in full.
#
# The data consists of 9,568 observations and 14 features.
#
# *If you intend to run through this notebook, you must first download the dataset and save it to a 'data' folder.*

# %%
df = pd.read_csv('data/loan_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# The first five observations can be seen below

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %% [markdown]
# ## Meaning of the features
#
# * credit.policy - credit policy, whether or not the client meets the credit underwriting criteria for Lending Club.  Boolean value, 1 for yes, 0 for no.
# * purpose - the purpose of the loan

# %%
df.purpose.unique()
# Out:
# array(['debt_consolidation', 'credit_card', 'all_other',
#        'home_improvement', 'small_business', 'major_purchase',
#        'educational'], dtype=object)

# %% [markdown]
# * int.rate - the interest rate of the loan
# * installment - the monthly installments owed
# * log.annual.inc - the log of the borrowers annual income
# * dti - the debt to income ratio of the borrower
# * fico - the borrowers FICO score
# * days.with.cr.line - the number of days the borrower has had a credit line
# * revol.bal - revolving balance, the amount unpaid by the borrower at the end of their credit cycle
# * revol.util - revolving utilization rate, the amount of credit used relative to their credit limit
# * inq.last.6mths - the number of inquiries the borrower has had by creditors in the past six months
# * delinq.2yrs - the number of times the borrower has been thirty or more days past due in the last two years
# * pub.rec - the number of derogitory public records of the borrower
# * not.fully.paid - a boolean depicting if the loan is not fully paid, 1: the loan is not fully paid, 0: the loan is fully paid

# %%
df.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %% [markdown]
# ## Feature preparation
#
# For ease of use, I am replacing the period in the feature names with an underscore.  I am also replacing the not fully paid column with a fully paid column as it makes interpreting visualizations and analysis easier for me.  Plus I would think the lending company would be more interested in whether or not a borrower will fully pay than if they will not fully pay.  However, not being in the finance industry, I may be wrong.

# %%
df.columns = [x.replace('.','_') for x in df.columns]
df.columns
# Out:
# Index(['credit_policy', 'purpose', 'int_rate', 'installment', 'log_annual_inc',
#        'dti', 'fico', 'days_with_cr_line', 'revol_bal', 'revol_util',
#        'inq_last_6mths', 'delinq_2yrs', 'pub_rec', 'not_fully_paid'],
#       dtype='object')

# %%
df['fully_paid'] = 1 - df.not_fully_paid
df.drop('not_fully_paid',axis=1,inplace=True)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Target column - fully paid

# %%
df.fully_paid.value_counts()
# Out:
# 1    8045
# 0    1533
# Name: fully_paid, dtype: int64

# %%
sns.countplot(x=df.fully_paid)
# Out:
# <AxesSubplot:xlabel='fully_paid', ylabel='count'>

# %% [markdown]
# As you can see in the dataset, there is definite imbalance in the target value of fully paid.  When creating a model I will need to deal with the imbalance.
#
# Methods of dealing with imbalance implemented in this project
# * Random undersampling and oversampling
# * Using class weights: balanced for ml algorithms with this option
# * Moving the classification threshold

# %% [markdown]
# ## Checking for missing values

# %%
df.isnull().sum()
# Out:
# credit_policy        0
# purpose              0
# int_rate             0
# installment          0
# log_annual_inc       0
# dti                  0
# fico                 0
# days_with_cr_line    0
# revol_bal            0
# revol_util           0
# inq_last_6mths       0
# delinq_2yrs          0
# pub_rec              0
# fully_paid           0
# dtype: int64

# %% [markdown]
# There appears to be no null values.  Now, from the descriptive statistics above, zeros for any numerical, non oridinal, feature, such as dti, may represent missing values.

# %%
may_be_missing = []
keys = df.describe().keys()
for i in range(1,len(keys)-1):
    if df.describe().loc['min',keys[i]]==0:
        may_be_missing.append(keys[i])
may_be_missing
# Out:
# ['dti', 'revol_bal', 'revol_util', 'inq_last_6mths', 'delinq_2yrs', 'pub_rec']

# %% [markdown]
# For these possibly missing values, I'm going to create a boolean possibly missing feature to accompany the numerical feature.

# %%
for val in may_be_missing:
    df[val+'_possmiss'] = 1*(df[val]==0)

# %% [markdown]
# ## Looking at individual features

# %% [markdown]
# ### Credit Policy

# %%
sns.countplot(x = 'credit_policy', data = df)
# Out:
# <AxesSubplot:xlabel='credit_policy', ylabel='count'>

# %% [markdown]
# More borrowers meet the credit policy than not.

# %% [markdown]
# ### Purpose

# %%
sns.countplot(y='purpose', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='purpose'>

# %% [markdown]
# The majority of borrowers are taking a loan out for debt consolidation.

# %% [markdown]
# ### Histograms of the remaining numeric features

# %%
features = ['int_rate', 'installment', 'log_annual_inc', 'dti',
       'fico', 'days_with_cr_line', 'revol_bal', 'revol_util',
       'inq_last_6mths', 'delinq_2yrs', 'pub_rec']

# %%
fig, axs = plt.subplots(4,3,figsize=[16,16])
r, c = (0,0)
for f in features:
    axs[r,c].hist(df[f], bins=25)
    axs[r,c].set_title(f)
    r = (r+1)%4
    c = (c+1)%3

# %% [markdown]
# Only log annual income looks somewhat normal although it does stretch.  It may need to be winsorized.  Days with credit line looks Poisson.

# %% [markdown]
# ## Looking at features with respect to fully paid

# %%
fig, axs = plt.subplots(4,3,figsize=[16,16])
r, c = (0,0)
for f in features:
    sns.boxplot(x='fully_paid',y=f,data=df, ax=axs[r,c])
    r = (r+1)%4
    c = (c+1)%3

# %% [markdown]
# From the bar charts it can be noted interest rate is slightly higher for those that have not fully paid as well as revol_util.  The rest are relatively similar.  Also there are definite outliers.  When working with linear models I will want to curb some maximum values.

# %% [markdown]
# When comparing categorical or ordinal counts with respect to whether the loan is fully paid or not, it is difficult to make interpretations using the imbalanced fully_paid.  Therefore I took a subsample to use with charts.

# %%
paid=df[df.fully_paid==1]
not_paid =df[df.fully_paid==0]
paid_subsample = paid.sample(n=1000, random_state=675)
not_paid_subsample = not_paid.sample(n=1000, random_state=675)
original_subsample = pd.concat([paid_subsample,not_paid_subsample])

# %% [markdown]
# ### Credit policy

# %%
sns.countplot(x = 'credit_policy', hue = 'fully_paid', data = original_subsample)
# Out:
# <AxesSubplot:xlabel='credit_policy', ylabel='count'>

# %% [markdown]
# For those that met the credit policy, more have fully paid.  Those that have not met the credit policy, more have not fully paid.

# %% [markdown]
# ### Purpose

# %%
fig, ax = plt.subplots(figsize=(12.8,4.8))
sns.countplot(x='purpose',hue='fully_paid',data=original_subsample)
# Out:
# <AxesSubplot:xlabel='purpose', ylabel='count'>

# %% [markdown]
# Those taking out loans for debt consolidation, home improvement, credit card payment, and major purchases appear more likely to fully pay.  Personal note: I'm still workinng on paying back my college loans twenty years later so I can see how for educational loans, more are not fully paid

# %% [markdown]
# ## Looking for correlation

# %%
loan_corr = df.select_dtypes(exclude='object').corr()
f = plt.figure(figsize=(9,9))
sns.heatmap(loan_corr,square=True,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The only strong correlation appears between whether revolving balance or revolving utilities are missing.  When working with a linear model, I will exclude these.

# %% [markdown]
# # Model creation
#
# The algorithms I chose to create machine learning models to predict loan repayment are:
#
# * K Nearest Neighbors
# * Random Forests
# * Logistic Regression
#
# I feel these three algorithms will offer a variety of models.  Logistic regression is a good binary classifier.  Random forests is an ensemble learning algorithm using decision trees.  This is robust to outliers but sensitive to imbalance and so will definitely need to handle imbalance.  K nearest neighbors is a similarity classifier that is good for data for which linear models may not fit.
#
# ## Evaluation metric
#
# To evaluate the model I chose to use f1 score along with looking at the precision and recall.  As the data is imbalanced, accuracy is not a good metric to use.  F1 is a balance of precision and recall.
#
# In the business sense, a lower precision would mean more clients that will not fully pay back their loan are being predicted as paying their loan back.  The lender could lose money by enrolling these clients. Whereas a low recall would mean more people that will fully pay their loan back are being predicted as not paying their loan back.  A potential consequence of this loss of potential clients, some potential clients could be turned down.
#
# Using precision alone or recall alone is not advisable as there is a tradeoff with precision and recall as can be seen in precision-recall curves.  As precision increases, recall decreases and vice versa.   F1 is a balance of the two and I feel is good to use for the evaluation metric. The f1 score of the training set will be compared to that of the test set to determine if there is possible overfitting or underfitting.

# %% [markdown]
# ## Functions I defined to assist

# %%
def get_preds(classifier, X_test, y_test, threshold):
    """
    gets the predicted y values when the threshold
    is not 0.5
    """
    y_preds = classifier.predict_proba(X_test)
    y_preds = y_preds[:,1]
    y_preds = 1 * (y_preds > threshold)
    return y_preds

# %%
def find_threshold(estimator, X_train, y_train, scoring='f1'):
    """
    finds the optimum threshold for moving the classification threshold
    """
    best_thresholds=[0]*5
    scores = cross_validate(estimator, X_train, y_train, scoring = scoring, return_estimator=True)
    for i in range(5):
        estimator_i = scores['estimator'][i]
        yhat = estimator_i.predict_proba(X_train)
        yhat = yhat[:,1]
        precision, recall, thresholds = precision_recall_curve(y_train,yhat)
        fscores = 2*precision*recall/(precision+recall)
        ix = np.argmax(fscores)
        best_thresholds[i] = thresholds[ix]
    return np.mean(best_thresholds)

# %%
def get_f1(classifier, X, y, threshold=None):
    """
    Returns the f1 score. This function needed to be created because of
    moving the classification threshold
    """
    if threshold is None:
        y_preds = classifier.predict(X)
    else:
        y_preds = get_preds(classifier, X, y, threshold)
    return f1_score(y, y_preds)

# %%
model_stats = {
    'model type' : [],
    'model' : [],
    'f1_score' : [],
    'precision_score' : [],
    'recall_score' : [],
    "percent '+' correct" : [],
    "percent '-' correct" : []
}

# %%
def print_scores(classifier, X_test, y_test, model_type, model, threshold=None, beta=1.0):
    """
    Prints the precision, recall, and f1 score and saves these stats plus 
    accuracy results to a dictionary
    """
    global model_stats
    if threshold is None:
        y_preds = classifier.predict(X_test)
    else:
        y_preds = get_preds(classifier, X_test, y_test, threshold)
    model_stats['model type'].append(model_type)
    model_stats['model'].append(model)
    scores = precision_recall_fscore_support(y_preds, y_test, beta=beta, average='binary')
    model_stats['precision_score'].append(round(scores[0],4))
    print("precision score: ",scores[0])
    model_stats['recall_score'].append(round(scores[1],4))
    print("recall score: ", scores[1])
    model_stats['f1_score'].append(round(scores[2],4))
    print("f1 score: ", scores[2])
    correct_classification = 1 - np.absolute(y_test - y_preds)
    scores_df = pd.DataFrame({'y_values': y_test, 'correct_classification': correct_classification})
    zeros = scores_df[scores_df.y_values == 0]
    ones = scores_df[scores_df.y_values == 1]
    correct_plus = 100*ones.correct_classification.sum()/ones.shape[0]
    correct_minus = 100*zeros.correct_classification.sum()/zeros.shape[0]
    model_stats["percent '+' correct"].append(round(correct_plus,2))
    model_stats["percent '-' correct"].append(round(correct_minus,2))

# %% [markdown]
# ## Splitting the data

# %%
X = df.drop('fully_paid', axis = 1)
y = df.fully_paid
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=675, test_size=0.2)

# %% [markdown]
# ## K nearest neighbors
#
# ### Base model

# %%
numeric_columns = ['int_rate', 'installment', 'log_annual_inc',
       'dti', 'fico', 'days_with_cr_line', 'revol_bal', 'revol_util',
       'inq_last_6mths', 'delinq_2yrs', 'pub_rec']
cat_column = ['purpose']

# %% [markdown]
# As KNN is sensitive to scale, the numeric values need to be scaled.  In addition, the one categorical variable needs to be one hot encoded.  To help avoid data leakage, I am using pipelines.

# %%
numeric_transformer = Pipeline(steps=[('scalar',StandardScaler())])
cat_transformer = Pipeline(steps=[('one_hot',OneHotEncoder(handle_unknown='ignore'))])

# %%
preprocessor = ColumnTransformer(transformers=[
    ('num',numeric_transformer,numeric_columns),
    ('cat',cat_transformer,cat_column)],
    remainder = 'passthrough')

# %%
knn1 = Pipeline(steps =[
    ('preprocessor',preprocessor),
    ('knn_classifier', KNeighborsClassifier())])

# %%
knn1.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('scalar',
#                                                                    StandardScaler())]),
#                                                   ['int_rate', 'installment',
#                                                    'log_annual_inc', 'dti',
#                                                    'fico', 'days_with_cr_line',
#                                                    'revol_bal', 'revol_util',
#                                                    'inq_last_6mths',
#                                                    'delinq_2yrs', 'pub_rec']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('one_hot',
# ...

# %%
get_f1(knn1,X_train,y_train)
# Out:
# 0.9198748271595953

# %% [markdown]
# The f1 score on the training set is 0.91.  This will be compared to the f1 score on the test set to see if there is any overfitting or underfitting.

# %%
print_scores(knn1, X_test, y_test, 'knn', 'base model')
# Out:
# precision score:  0.9616573902288188
# recall score:  0.8441910966340934
# f1 score:  0.8991037872217404

# %% [markdown]
# The f1 score on the test set slightly dropped.  No overfitting or underfitting is apparent.

# %%
fig, axs = plt.subplots(1,2, figsize=(10,6))
axs[0].set_title("Counts")
plot_confusion_matrix(knn1 ,X_test, y_test, ax = axs[0])
axs[1].set_title("Percent of True")
plot_confusion_matrix(knn1 ,X_test, y_test, ax = axs[1], normalize='true', values_format='.2%')
axs[1].set_title("Percent of True")
# Out:
# Text(0.5, 1.0, 'Percent of True')

# %% [markdown]
# The effect of the imbalanced set can be seen in the confusion matrix as the base model heavily predicts the positive target.
#
# ### Moving the classification threshold

# %%
find_threshold(knn1, X_train, y_train)
# Out:
# 0.6

# %%
plot_precision_recall_curve(knn1 ,X_test, y_test)

# %% [markdown]
# Moving the threshold from 0.5 to 0.6 delivers no change precision and recall as seen by this graph.  This make sense as the only possible probabilites with the standard 5 neighbors are 0, 0.2, 0.4, 0.6, 0.8 and 1.  There is no difference between 0.5 and 0.6.  Because of this, I am going to change the threshold to 0.7

# %%
get_f1(knn1,X_train,y_train, threshold=0.7)
# Out:
# 0.9039565798788641

# %%
print_scores(knn1, X_test, y_test, 'knn', 'moving threshold', threshold=0.7)
# Out:
# precision score:  0.8503401360544217
# recall score:  0.8572319201995012
# f1 score:  0.8537721204594846

# %% [markdown]
# There is a slight drop in f1 scores for the test set.  I do not feel there is overfitting.

# %%
y_preds = get_preds(knn1, X_test, y_test, threshold=0.7)
knn1_cm1 = confusion_matrix(y_test, y_preds)
knn1_cm2 = confusion_matrix(y_test, y_preds, normalize='true')
fig, axs = plt.subplots(1,2, figsize=(10,6))
knn_cm_disp1 = ConfusionMatrixDisplay(knn1_cm1, display_labels=knn1.classes_)
knn_cm_disp1.plot(ax=axs[0])
axs[0].set_title("Counts")
knn_cm_disp2 = ConfusionMatrixDisplay(knn1_cm2, display_labels=knn1.classes_)
knn_cm_disp2.plot(ax=axs[1], values_format='.2%')
axs[1].set_title("Percent of True")
# Out:
# Text(0.5, 1.0, 'Percent of True')

# %% [markdown]
# Moving the threshold reduces the number of true positives, increases the number of true negatives, reduces the number of false positives and increases the number of false negatives.  The f1 score slightly decreases.  I feel this model is better than the base model.
#
# ### Base model with undersampling

# %%
knn2 = imbPipeline(steps =[
    ('preprocessor',preprocessor),
    ('sampler',RandomUnderSampler(random_state=625)),
    ('knn_classifier', KNeighborsClassifier())])

# %%
knn2.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('scalar',
#                                                                    StandardScaler())]),
#                                                   ['int_rate', 'installment',
#                                                    'log_annual_inc', 'dti',
#                                                    'fico', 'days_with_cr_line',
#                                                    'revol_bal', 'revol_util',
#                                                    'inq_last_6mths',
#                                                    'delinq_2yrs', 'pub_rec']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('one_hot',
# ...

# %%
get_f1(knn2,X_train,y_train)
# Out:
# 0.7658227848101266

# %%
print_scores(knn2, X_test, y_test, 'knn', 'undersampling')
# Out:
# precision score:  0.6072974644403216
# recall score:  0.8598949211908932
# f1 score:  0.7118521203334542

# %% [markdown]
# The f1 scores are similar so no overfitting or underfitting is apparent.

# %%
fig, axs = plt.subplots(1,2, figsize=(10,6))
axs[0].set_title("Counts")
plot_confusion_matrix(knn2 ,X_test, y_test, ax = axs[0])
axs[1].set_title("Percent of True")
plot_confusion_matrix(knn2 ,X_test, y_test, ax = axs[1], normalize='true', values_format='.2%')

# %% [markdown]
# As can be seen there are many more incorrect predictions using a subsample.  Undersampling does better at balancing the number of true positives and true negatives but at the cost of f1.  Although it is a more balanced predictor, f1 suffers and there are many more misclassifications.  I feel this does not perform as well as moving the threshold.

# %% [markdown]
# ### Base model with Oversampling

# %%
knn3 = imbPipeline(steps =[
    ('preprocessor',preprocessor),
    ('sampler',RandomOverSampler(random_state=625)),
    ('knn_classifier', KNeighborsClassifier())])

# %%
knn3.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('scalar',
#                                                                    StandardScaler())]),
#                                                   ['int_rate', 'installment',
#                                                    'log_annual_inc', 'dti',
#                                                    'fico', 'days_with_cr_line',
#                                                    'revol_bal', 'revol_util',
#                                                    'inq_last_6mths',
#                                                    'delinq_2yrs', 'pub_rec']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('one_hot',
# ...

# %%
get_f1(knn3,X_train,y_train)
# Out:
# 0.8690642458100558

# %%
print_scores(knn3, X_test, y_test, 'knn', 'oversampling')
# Out:
# precision score:  0.6821273964131107
# recall score:  0.8691883372734437
# f1 score:  0.7643797643797644

# %% [markdown]
# There is a moderate drop in f1 score.  The model may be overfitting.

# %%
fig, axs = plt.subplots(1,2, figsize=(10,6))
axs[0].set_title("Counts")
plot_confusion_matrix(knn3 ,X_test, y_test, ax = axs[0])
axs[1].set_title("Percent of True")
plot_confusion_matrix(knn3 ,X_test, y_test, ax = axs[1], normalize='true', values_format='.2%')

# %% [markdown]
# With respect to precision, recall, and f1, oversampling performed better than undersampling.  However the test set f1 score is moderately lower than the training set f1 score.  As noted, this model may be overfitting.  Like with undersampling, many more classification errors are made.  F1 suffers because of this.

# %% [markdown]
# ## Random Forests
#
# ### Ordinal encoding the one categorical variable and splitting the data

# %%
X_rf = X.copy()
le = LabelEncoder()
X_rf['purpose'] = le.fit_transform(X.purpose.values)
Xrf_train, Xrf_test, y_train, y_test = train_test_split(X_rf, y, random_state=675, test_size=0.2)

# %% [markdown]
# ### Base model

# %%
rf1 = RandomForestClassifier()
rf1.fit(Xrf_train,y_train)
get_f1(rf1,Xrf_train,y_train)
# Out:
# 1.0

# %% [markdown]
# Given a f1 score of 1, I am cetain the model is overfitting.  A confusion matrix will be plotted to test this.

# %%
plot_confusion_matrix(rf1 ,Xrf_train, y_train, normalize='true', values_format='.2%')

# %% [markdown]
# Yes, the model is overfitting.  To stop this, I'm going to set the maximum depth of the tree to 10 and refit the model as the base model.

# %%
rf1 = RandomForestClassifier(max_depth=10)
rf1.fit(Xrf_train,y_train)
get_f1(rf1,Xrf_train,y_train)
# Out:
# 0.925891249549874

# %%
print_scores(rf1, Xrf_test, y_test, 'random forests', 'base model')
# Out:
# precision score:  0.9987631416202845
# recall score:  0.8451072736787022
# f1 score:  0.915532879818594

# %% [markdown]
# As both f1 scores are close, overfitting is not apparent.  As f1 scores are high, the model is not underfitting.

# %%
fig, axs = plt.subplots(1,2, figsize=(10,6))
axs[0].set_title("Counts")
plot_confusion_matrix(rf1 ,Xrf_test, y_test, ax = axs[0])
axs[1].set_title("Percent of True")
plot_confusion_matrix(rf1 ,Xrf_test, y_test, ax = axs[1], normalize='true', values_format='.2%')

# %% [markdown]
# As can be seen imbalance is causing the model to mostly predict positive, more so with random forests than knn.

# %% [markdown]
# ### Looking at feature importance

# %%
rf_overfitting = RandomForestClassifier()
rf_overfitting.fit(Xrf_train, y_train)
fi = pd.DataFrame({'features':X.columns,'importance':rf_overfitting.feature_importances_})
fi.sort_values(by='importance',ascending=False,inplace=True)
f = plt.figure(figsize=(8,10))
sns.barplot(y='features', x='importance', data=fi)
# Out:
# <AxesSubplot:xlabel='importance', ylabel='features'>

# %% [markdown]
# The top five features based on feature importance are installment, revol_bal, days_with_cr_line, revol_util, and log_annual_inc.  A large amount of features are equally important, nothing stands out as more important. Pub_rec is less important that some of the features engineered to represent whether possible values are missing.  I would expect a better fitting model would have higher relevancy for some features.  More data should be collected to improve this dataset.
#
# ### Moving the threshold

# %%
rf_t = find_threshold(rf1, Xrf_train, y_train)
rf_t
# Out:
# 0.7096883153045328

# %% [markdown]
# Using cross validation the adjusted threshold is calculated.  This threshold of about 0.7 will result in more negative predictions.

# %%
get_f1(rf1,Xrf_train,y_train, threshold=rf_t)
# Out:
# 0.9536532577057989

# %%
print_scores(rf1, Xrf_test, y_test, 'random forests', 'moving threshold', threshold=rf_t)
# Out:
# precision score:  0.9214594928880643
# recall score:  0.8592848904267589
# f1 score:  0.8892867800656519

# %% [markdown]
# Moving the threshold caused a slight decrease in precision and f1 scores while recall improved.  There still may be slight overfitting with the change in f1 scores.

# %%
y_preds = get_preds(rf1, Xrf_test, y_test, threshold=rf_t)
rf_cm1 = confusion_matrix(y_test, y_preds)
rf_cm2 = confusion_matrix(y_test, y_preds, normalize='true')
fig, axs = plt.subplots(1,2, figsize=(10,6))
rf_cm_disp1 = ConfusionMatrixDisplay(rf_cm1, display_labels=rf1.classes_)
rf_cm_disp2 = ConfusionMatrixDisplay(rf_cm2, display_labels=rf1.classes_)
rf_cm_disp1.plot(ax=axs[0])
axs[0].set_title("Counts")
rf_cm_disp2.plot(ax=axs[1], values_format='.2%')
axs[1].set_title("Percent of True")
# Out:
# Text(0.5, 1.0, 'Percent of True')

# %% [markdown]
# The model is slightly better although imbalance can still be obvserved.

# %% [markdown]
# ### Using class_weights: balanced

# %%
rf2 = RandomForestClassifier(class_weight='balanced', max_depth=10)
rf2.fit(Xrf_train,y_train)
get_f1(rf2,Xrf_train,y_train)
# Out:
# 0.9388880138604504

# %%
print_scores(rf2, Xrf_test, y_test, 'random forests', 'balanced weights')
# Out:
# precision score:  0.860235003092146
# recall score:  0.8639751552795031
# f1 score:  0.86210102262163

# %% [markdown]
# There may be slight overfitting due to the drop in f1 score.

# %%
fig, axs = plt.subplots(1,2, figsize=(10,6))
axs[0].set_title("Counts")
plot_confusion_matrix(rf2 ,Xrf_test, y_test, ax = axs[0])
axs[1].set_title("Percent of True")
plot_confusion_matrix(rf2 ,Xrf_test, y_test, ax = axs[1], normalize='true', values_format='.2%')

# %% [markdown]
# There is a slight drop in f1 scores from the model creating using threshold moving.  Fewer false positives and more true negatives are being classified.  This model may be better at the expense of the drop in f1 score.  There is also a drop in precision.  At first it seemed confusing that precision was going down but also the number of false positives are going down.  The reason for this is that there are also fewer true positives being predicted with this model.

# %% [markdown]
# ### Random Forests with undersampling

# %%
rf3 = imbPipeline(steps =[
    ('sampler',RandomUnderSampler(random_state=625)),
    ('rf_classifier', RandomForestClassifier(max_depth=10))])
rf3.fit(Xrf_train,y_train)
get_f1(rf3,Xrf_train,y_train)
# Out:
# 0.8122805438012065

# %%
print_scores(rf3,Xrf_test,y_test, 'random forests', 'undersampling')
# Out:
# precision score:  0.6221397649969078
# recall score:  0.8847845206684257
# f1 score:  0.7305737109658679

# %% [markdown]
# Both f1s have suffered from undersampling.  I do not feel there is underfitting going on.

# %%
fig, axs = plt.subplots(1,2, figsize=(10,6))
axs[0].set_title("Counts")
plot_confusion_matrix(rf3 ,Xrf_test, y_test, ax = axs[0])
axs[1].set_title("Percent of True")
plot_confusion_matrix(rf3 ,Xrf_test, y_test, ax = axs[1], normalize='true', values_format='.2%')

# %% [markdown]
# Even though there is more balance between the percentage of true true positives, and the percentage of true, true negatives, this model suffers from more misclassification than using threshold moving or class weights balanced.  This is not good as undersampling reduces the training set size.

# %% [markdown]
# ### Random forests with oversampling

# %%
rf4 = imbPipeline(steps =[
    ('sampler',RandomOverSampler(random_state=625)),
    ('rf_classifier', RandomForestClassifier(max_depth=10))])
rf4.fit(Xrf_train,y_train)
get_f1(rf4,Xrf_train,y_train)
# Out:
# 0.9176643049108233

# %%
print_scores(rf4,Xrf_test,y_test, 'random forests', 'oversampling')
# Out:
# precision score:  0.7717996289424861
# recall score:  0.8684759916492694
# f1 score:  0.8172888015717092

# %% [markdown]
# From the moderate drop in f1 scores, it appears overfitting is still apparent.

# %%
fig, axs = plt.subplots(1,2, figsize=(10,6))
axs[0].set_title("Counts")
plot_confusion_matrix(rf4 ,Xrf_test, y_test, ax = axs[0])
axs[1].set_title("Percent of True")
plot_confusion_matrix(rf4 ,Xrf_test, y_test, ax = axs[1], normalize='true', values_format='.2%')

# %% [markdown]
# From the f1 score, this model performs better than underfitting.  But, with a large drop in precision this model does not perform as well as using class weights balanced or moving the threshold.

# %% [markdown]
# ## Logistic Regression
#
# ### Base model

# %%
X_lr = X.copy()
X_lr.drop(['revol_util_possmiss','revol_bal_possmiss'], axis=1, inplace = True)
Xlr_train, Xlr_test = train_test_split(X_lr, random_state=675, test_size=0.2)

# %% [markdown]
# #### Handling outliers

# %% [markdown]
# I chose to adjust for extreme values for interest rate, log annual income, inquiries the last 6 months, and the number of public records.  More exploration of outliers can be found in my EDA notebook under the 'notebooks' folder.

# %%
Xlr_train = Xlr_train.copy()
Xlr_train['int_rate'] = Xlr_train['int_rate'].apply(lambda x: min([x,0.2]))
Xlr_train['log_annual_inc'] = winsorize(Xlr_train.log_annual_inc, limits=(0.1,0.1))
Xlr_train['inq_last_6mths'] = Xlr_train['inq_last_6mths'].apply(lambda x : min([x,15]))
Xlr_train['pub_rec'] = Xlr_train['pub_rec'].apply(lambda x : min([x,4]))

# %% [markdown]
# #### Training model

# %%
X_lr_numfeat = ['int_rate', 'installment', 'log_annual_inc',
       'dti', 'fico', 'days_with_cr_line', 'revol_bal', 'revol_util',
       'inq_last_6mths', 'delinq_2yrs', 'pub_rec']

# %%
catlr_transformer = Pipeline(steps=[('one_hot',OneHotEncoder(handle_unknown='error', drop='first'))])
preprocessor_lr = ColumnTransformer(transformers=[
    ('num',numeric_transformer,X_lr_numfeat),
    ('cat',catlr_transformer,cat_column)],
    remainder = 'passthrough')
lr1 = Pipeline(steps =[
    ('preprocessor',preprocessor_lr),
    ('lr_classifier', LogisticRegression(penalty='none'))])
lr1.fit(Xlr_train, y_train)
get_f1(lr1,Xlr_train,y_train)
# Out:
# 0.9124160594370624

# %%
print_scores(lr1, Xlr_test, y_test, 'logistic regression', 'base model')
# Out:
# precision score:  0.9901051329622759
# recall score:  0.8493368700265252
# f1 score:  0.9143346659051971

# %% [markdown]
# From f1 scores no overfitting or underfitting is apparent.

# %%
fig, axs = plt.subplots(1,2, figsize=(10,6))
axs[0].set_title("Counts")
plot_confusion_matrix(lr1 ,Xlr_test, y_test, ax = axs[0])
axs[1].set_title("Percent of True")
plot_confusion_matrix(lr1 ,Xlr_test, y_test, ax = axs[1], normalize='true', values_format='.2%')

# %% [markdown]
# As was also seen with KNN and the adjusted random forests base model, the base model for logistic regression favors the fully paid outcome.  Slighlty more true negatives and fewer false negatives are predicted with the base model of logistic regression than with the base model of KNN.

# %% [markdown]
# ### Logistic regression with selected features
#
# From the EDA and feature importance graph, I decided to try to build a base model with only selected features.  If it performs well, it can be built up.

# %%
lr_selected_num = ['credit_policy']+list(fi.features[:5])
lr_selected_cat = ['purpose']
Xlrs_train = Xlr_train[lr_selected_num+lr_selected_cat]
Xlrs_test = Xlr_test[lr_selected_num+lr_selected_cat]
preprocessor_lr2 = ColumnTransformer(transformers=[
    ('num',numeric_transformer,lr_selected_num),
    ('cat',catlr_transformer,lr_selected_cat)])
lr_selected = Pipeline(steps =[
    ('preprocessor',preprocessor_lr2),
    ('lr_classifier', LogisticRegression(penalty='none'))])
lr_selected.fit(Xlrs_train, y_train)
get_f1(lr_selected,Xlrs_train,y_train)
# Out:
# 0.9120660216277745

# %%
print_scores(lr_selected, Xlrs_test, y_test, 'logistic regression','selected features')
# Out:
# precision score:  0.9969078540507111
# recall score:  0.8461942257217848
# f1 score:  0.9153889835320841

# %% [markdown]
# From the change in f1 scores, there appears to be no overfitting or underfitting.

# %%
fig, axs = plt.subplots(1,2, figsize=(10,6))
axs[0].set_title("Counts")
plot_confusion_matrix(lr_selected ,Xlrs_test, y_test, ax = axs[0])
axs[1].set_title("Percent of True")
plot_confusion_matrix(lr_selected ,Xlrs_test, y_test, ax = axs[1], normalize='true', values_format='.2%')

# %% [markdown]
# Selecting features for logistic regression made the model worse.

# %% [markdown]
# ### Moving the threshold

# %%
lr_t = find_threshold(lr1, Xlr_train, y_train)
lr_t
# Out:
# 0.4250992286205042

# %% [markdown]
# Since I want to predict fewer positives, 0.42 seems way too low.  Going to try 0.7

# %%
get_f1(lr1,Xlr_train,y_train, threshold=0.7)
# Out:
# 0.8962066905615292

# %%
print_scores(lr1, Xlr_test, y_test, 'logistic regression', 'moving threshold', threshold=0.7)
# Out:
# precision score:  0.9189857761286333
# recall score:  0.863451481696688
# f1 score:  0.8903535050928699

# %% [markdown]
# From the change in f1 scores, no underfitting or overfitting is apparent.

# %%
lr_y_preds = get_preds(lr1, Xlr_test, y_test, threshold=0.7)
lr_cm1 = confusion_matrix(y_test, lr_y_preds)
lr_cm2 = confusion_matrix(y_test, lr_y_preds, normalize='true')
fig, axs = plt.subplots(1,2, figsize=(10,6))
lr_cm_disp1 = ConfusionMatrixDisplay(lr_cm1, display_labels=lr1.classes_)
lr_cm_disp1.plot(ax=axs[0])
axs[0].set_title("Counts")
lr_cm_disp2 = ConfusionMatrixDisplay(lr_cm2, display_labels=lr1.classes_)
lr_cm_disp2.plot(ax=axs[1], values_format='.2%')
axs[1].set_title("Percent of true")
# Out:
# Text(0.5, 1.0, 'Percent of true')

# %% [markdown]
# need to finish

# %% [markdown]
# ### Using class weights: balanced

# %%
lr2 = Pipeline(steps =[
    ('preprocessor',preprocessor_lr),
    ('lr_classifier', LogisticRegression(penalty='none', class_weight='balanced'))])
lr2.fit(Xlr_train,y_train)
get_f1(lr2,Xlr_train,y_train)
# Out:
# 0.7537199026061864

# %%
print_scores(lr2, Xlr_test, y_test, 'logistic regression', 'balanced weights')
# Out:
# precision score:  0.640074211502783
# recall score:  0.8914728682170543
# f1 score:  0.7451403887688985

# %% [markdown]
# Using balanced class weights, there is a definite drop in f1 from previous models.  From the change in f1, no overfitting or underfitting is apparent.

# %%
fig, axs = plt.subplots(1,2, figsize=(10,6))
axs[0].set_title("Counts")
plot_confusion_matrix(lr2 ,Xlr_test, y_test, ax = axs[0])
axs[1].set_title("Percent of True")
plot_confusion_matrix(lr2 ,Xlr_test, y_test, ax = axs[1], normalize='true', values_format='.2%')

# %% [markdown]
# ### Logistic regression with undersampling

# %%
lr4 = imbPipeline(steps =[
    ('preprocessor',preprocessor_lr),
    ('sampler',RandomUnderSampler(random_state=625)),
    ('lr_classifier', LogisticRegression(penalty='none'))])
lr4.fit(Xlr_train,y_train)
get_f1(lr4,Xlr_train,y_train)
# Out:
# 0.7551829817919596

# %%
print_scores(lr4, Xlr_test, y_test, 'logistic regression', 'undersampling')
# Out:
# precision score:  0.6363636363636364
# recall score:  0.8901384083044983
# f1 score:  0.7421565091958168

# %% [markdown]
# No overfitting or underfitting is apparent from the f1 scores.

# %%
fig, axs = plt.subplots(1,2, figsize=(10,6))
axs[0].set_title("Counts")
plot_confusion_matrix(lr4 ,Xlr_test, y_test, ax = axs[0])
axs[1].set_title("Percent of True")
plot_confusion_matrix(lr4 ,Xlr_test, y_test, ax = axs[1], normalize='true', values_format='.2%')

# %% [markdown]
# ### Logistic Regression with oversampling

# %%
lr5 = imbPipeline(steps =[
    ('preprocessor',preprocessor_lr),
    ('sampler',RandomOverSampler(random_state=625)),
    ('lr_classifier', LogisticRegression(penalty='none'))])
lr5.fit(Xlr_train,y_train)
get_f1(lr5,Xlr_train,y_train)
# Out:
# 0.7512424324568537

# %%
print_scores(lr5, Xlr_test, y_test, 'logistic regression', 'oversampling')
# Out:
# precision score:  0.6431663574520717
# recall score:  0.896551724137931
# f1 score:  0.7490097227223622

# %% [markdown]
# No overfitting or underfitting is apparent from the f1 scores.

# %%
fig, axs = plt.subplots(1,2, figsize=(10,6))
axs[0].set_title("Counts")
plot_confusion_matrix(lr5 ,Xlr_test, y_test, ax = axs[0])
axs[1].set_title("Percent of True")
plot_confusion_matrix(lr5 ,Xlr_test, y_test, ax = axs[1], normalize='true', values_format='.2%')

# %% [markdown]
# ### Comparing all models

# %%
stats = pd.DataFrame(model_stats)
stats
# Out:
#              model type              model  f1_score  precision_score  \
# 0                   knn         base model    0.8991           0.9617
# 1                   knn   moving threshold    0.8538           0.8503
# 2                   knn      undersampling    0.7119           0.6073
# 3                   knn       oversampling    0.7644           0.6821
# 4        random forests         base model    0.9155           0.9988
# 5        random forests   moving threshold    0.8893           0.9215
# 6        random forests   balanced weights    0.8621           0.8602
# 7        random forests      undersampling    0.7306           0.6221
# 8        random forests       oversampling    0.8173           0.7718
# 9   logistic regression         base model    0.9143           0.9901
# 10  logistic regression  selected features    0.9154           0.9969
# 11  logistic regression   moving threshold    0.8904           0.9190
# ...

# %% [markdown]
# By looking at f1 score and precision, moving the threshold performed better for each classifier type than did undersampling, oversampling, or adjusting the class weights.

# %%
stats[stats.model=='moving threshold']
# Out:
#              model type             model  f1_score  precision_score  \
# 1                   knn  moving threshold    0.8538           0.8503
# 5        random forests  moving threshold    0.8893           0.9215
# 11  logistic regression  moving threshold    0.8904           0.9190
#
#     recall_score  percent '+' correct  percent '-' correct
# 1         0.8572                85.03                23.41
# 5         0.8593                92.15                18.39
# 11        0.8635                91.90                21.40

# %% [markdown]
# Of the three, logistic regression performed best in all of f1 score, precision, and recall.  It did however favor positive outcomes more so than KNN, if you look at the percent '-' correct column.
#
# Comparing the timing of the models.

# %%
start = time.time()
knn1.fit(X_train,y_train)
end = time.time()
times = [end - start]
start = time.time()
rf1.fit(Xrf_train,y_train)
end = time.time()
times.append(end - start)
start = time.time()
lr1.fit(Xlr_train, y_train)
end = time.time()
times.append(end - start)
print("K nearest neighbors took ",times[0]," seconds.")
print("Random forests took ",times[1]," seconds")
print("Logistic regression took ",times[2]," seconds")
# Out:
# K nearest neighbors took  0.041153907775878906  seconds.
# Random forests took  2.648824453353882  seconds
# Logistic regression took  0.24188446998596191  seconds
